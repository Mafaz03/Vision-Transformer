# %%
EXTRA_TOKENS = [
            f"<loc{i:04d}>" for i in range(1024)
        ]

EXTRA_TOKENS += [
            f"<seg{i:03d}>" for i in range (128)
        ]
EXTRA_TOKENS[1000:]
# Out:
# ['<loc1000>',
#  '<loc1001>',
#  '<loc1002>',
#  '<loc1003>',
#  '<loc1004>',
#  '<loc1005>',
#  '<loc1006>',
#  '<loc1007>',
#  '<loc1008>',
#  '<loc1009>',
#  '<loc1010>',
#  '<loc1011>',
#  '<loc1012>',
#  '<loc1013>',
#  '<loc1014>',
#  '<loc1015>',
#  '<loc1016>',
#  '<loc1017>',
#  '<loc1018>',
#  '<loc1019>',
#  '<loc1020>',
#  '<loc1021>',
#  '<loc1022>',
#  '<loc1023>',
#  '<seg000>',
#  '<seg001>',
#  '<seg002>',
#  '<seg003>',
#  '<seg004>',
#  '<seg005>',
#  '<seg006>',
#  '<seg007>',
#  '<seg008>',
#  '<seg009>',
#  '<seg010>',
#  '<seg011>',
#  '<seg012>',
#  '<seg013>',
#  '<seg014>',
#  '<seg015>',
#  '<seg016>',
#  '<seg017>',
#  '<seg018>',
#  '<seg019>',
#  '<seg020>',
#  '<seg021>',
#  '<seg022>',
#  '<seg023>',
#  '<seg024>',
#  '<seg025>',
#  '<seg026>',
#  '<seg027>',
#  '<seg028>',
#  '<seg029>',
#  '<seg030>',
#  '<seg031>',
#  '<seg032>',
#  '<seg033>',
#  '<seg034>',
#  '<seg035>',
#  '<seg036>',
#  '<seg037>',
#  '<seg038>',
#  '<seg039>',
#  '<seg040>',
# ...
